# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt

# %%
# #import data csv 
# review = pd.read_excel('ReviewBg.xlsx',sheet_name="Data")
# review #tampilkan info dari dataframe diabetes
gsheetid = "1-pYSqXh_lqOqV9tHUCX3kyxQaJKYA1hlB-9ae4NlO20"
sheet_name = "Data"

gsheet_url = "https://docs.google.com/spreadsheets/d/{}/gviz/tq?tqx=out:csv&sheet={}".format(gsheetid, sheet_name)
gsheet_url
# Out:
# 'https://docs.google.com/spreadsheets/d/1-pYSqXh_lqOqV9tHUCX3kyxQaJKYA1hlB-9ae4NlO20/gviz/tq?tqx=out:csv&sheet=Data'

# %%
review = pd.read_csv(gsheet_url)
review
# Out:
#                  Name                                            Comment  \
# 0       pendaki galau  Nice review. Smart description. Gak sekedar re...
# 1    Romi Rendra Bayu  Gw orng bandung tp ga tau dmn letaknya bbq mou...
# 2    Ahsanul Kholiqin  BURGER Panggang holic cibubur bang coba,pasti ...
# 3        Alifia Putri  Bang sound nya di Intro gak begitu kedengeran ...
# 4       Catur Goprazt  Nonton ini, bikinlaper transtv jd keliatan cup...
# ..                ...                                                ...
# 220      harist adnan  trailer nya bukan kek iklan nih <br /><br /><b...
# 221    Bagas Prasetyo                                      Masih lama. 😅
# 222       Fachri azis                                 Anjay keluar rumah
# 223     ade syahrudin                         Akhirnya keluar rumah mank
# 224         Donny DPS                                                  👍
#
#                      Time  Likes  Reply Count
# ...

# %%
# ?WordCloud

# %%
text = ""

# Start with one review:
for i in range(len(review)) :
    text = text + str(review.Comment[i])

# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
